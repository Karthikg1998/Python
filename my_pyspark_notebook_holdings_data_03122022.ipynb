# %% [markdown]
# HOLDINGS DATA

# %%
from pyspark.sql.functions import desc

# %%
holdings = spark.read.csv("/FileStore/tables/my_holdings_031222.csv",header='true')
display(holdings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Instrument</th><th>Qty.</th><th>Avg. cost</th><th>LTP</th><th>Cur. val</th><th>P&L</th><th>Net chg.</th><th>Day chg.</th></tr></thead><tbody><tr><td>ADANIPORTS</td><td>15</td><td>837.33</td><td>886.2</td><td>13293</td><td>733.05</td><td>5.84</td><td>-0.24</td></tr><tr><td>ALLCARGO</td><td>10</td><td>377.6</td><td>440.15</td><td>4401.5</td><td>625.5</td><td>16.57</td><td>0</td></tr><tr><td>DEEPAKNTR</td><td>2</td><td>2073.75</td><td>2211.5</td><td>4423</td><td>275.5</td><td>6.64</td><td>0</td></tr><tr><td>EXIDEIND</td><td>40</td><td>157.98</td><td>190.6</td><td>7624</td><td>1304.7</td><td>20.65</td><td>0</td></tr><tr><td>HDFCLIFE</td><td>16</td><td>536.35</td><td>590</td><td>9440</td><td>858.4</td><td>10</td><td>0</td></tr><tr><td>HINDUNILVR</td><td>8</td><td>2557.43</td><td>2615.3</td><td>20922.4</td><td>463</td><td>2.26</td><td>0</td></tr><tr><td>LANCER</td><td>8</td><td>364</td><td>447.15</td><td>3577.2</td><td>665.2</td><td>22.84</td><td>0</td></tr><tr><td>NIFTYBEES</td><td>48</td><td>190.57</td><td>204.81</td><td>9830.88</td><td>683.46</td><td>7.47</td><td>-0.01</td></tr><tr><td>SAREGAMA</td><td>5</td><td>398.37</td><td>381.9</td><td>1909.5</td><td>-82.35</td><td>-4.13</td><td>0</td></tr><tr><td>SCHAEFFLER</td><td>13</td><td>2957.88</td><td>2809.4</td><td>36522.2</td><td>-1930.25</td><td>-5.02</td><td>0.21</td></tr><tr><td>SHREDIGCEM</td><td>20</td><td>66.58</td><td>70.25</td><td>1405</td><td>73.5</td><td>5.52</td><td>0</td></tr><tr><td>TATASTEEL</td><td>40</td><td>101.55</td><td>112.05</td><td>4482</td><td>420</td><td>10.34</td><td>0</td></tr><tr><td>TCS</td><td>10</td><td>3148.67</td><td>3439.25</td><td>34392.5</td><td>2905.85</td><td>9.23</td><td>0</td></tr><tr><td>TRIDENT</td><td>125</td><td>36.85</td><td>37.55</td><td>4693.75</td><td>87.25</td><td>1.89</td><td>0</td></tr></tbody></table></div>

# %%
holdings.collect()
# Out:
# Out[14]: [Row(Instrument='ADANIPORTS', Qty.='15', Avg. cost='837.33', LTP='886.2', Cur. val='13293', P&L='733.05', Net chg.='5.84', Day chg.='-0.24'),
#  Row(Instrument='ALLCARGO', Qty.='10', Avg. cost='377.6', LTP='440.15', Cur. val='4401.5', P&L='625.5', Net chg.='16.57', Day chg.='0'),
#  Row(Instrument='DEEPAKNTR', Qty.='2', Avg. cost='2073.75', LTP='2211.5', Cur. val='4423', P&L='275.5', Net chg.='6.64', Day chg.='0'),
#  Row(Instrument='EXIDEIND', Qty.='40', Avg. cost='157.98', LTP='190.6', Cur. val='7624', P&L='1304.7', Net chg.='20.65', Day chg.='0'),
#  Row(Instrument='HDFCLIFE', Qty.='16', Avg. cost='536.35', LTP='590', Cur. val='9440', P&L='858.4', Net chg.='10', Day chg.='0'),
#  Row(Instrument='HINDUNILVR', Qty.='8', Avg. cost='2557.43', LTP='2615.3', Cur. val='20922.4', P&L='463', Net chg.='2.26', Day chg.='0'),
#  Row(Instrument='LANCER', Qty.='8', Avg. cost='364', LTP='447.15', Cur. val='3577.2', P&L='665.2', Net chg.='22.84', Day chg.='0'),
#  Row(Instrument='NIFTYBEES', Qty.='48', Avg. cost='190.57', LTP='204.81', Cur. val='9830.88', P&L='683.46', Net chg.='7.47', Day chg.='-0.01'),
#  Row(Instrument='SAREGAMA', Qty.='5', Avg. cost='398.37', LTP='381.9', Cur. val='1909.5', P&L='-82.35', Net chg.='-4.13', Day chg.='0'),
#  Row(Instrument='SCHAEFFLER', Qty.='13', Avg. cost='2957.88', LTP='2809.4', Cur. val='36522.2', P&L='-1930.25', Net chg.='-5.02', Day chg.='0.21'),
#  Row(Instrument='SHREDIGCEM', Qty.='20', Avg. cost='66.58', LTP='70.25', Cur. val='1405', P&L='73.5', Net chg.='5.52', Day chg.='0'),
#  Row(Instrument='TATASTEEL', Qty.='40', Avg. cost='101.55', LTP='112.05', Cur. val='4482', P&L='420', Net chg.='10.34', Day chg.='0'),
#  Row(Instrument='TCS', Qty.='10', Avg. cost='3148.67', LTP='3439.25', Cur. val='34392.5', P&L='2905.85', Net chg.='9.23', Day chg.='0'),
#  Row(Instrument='TRIDENT', Qty.='125', Avg. cost='36.85', LTP='37.55', Cur. val='4693.75', P&L='87.25', Net chg.='1.89', Day chg.='0')]

# %%
holdings.describe().show()
# Out:
# +-------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+--------------------+
# |summary|Instrument|              Qty.|         Avg. cost|               LTP|          Cur. val|               P&L|         Net chg.|            Day chg.|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+--------------------+
# |  count|        14|                14|                14|                14|                14|                14|               14|                  14|
# |   mean|      null|25.714285714285715| 986.0649999999999|1031.1507142857142|11208.352142857142|505.91499999999996|7.864285714285715|-0.00285714285714...|
# | stddev|      null| 31.96014000987088|1156.6354603746825|1187.6298012652328| 11488.26527780157|1013.3838540314023|8.153843562097867|  0.0884419471855862|
# |    min|ADANIPORTS|                10|            101.55|            112.05|             13293|          -1930.25|            -4.13|               -0.01|
# |    max|   TRIDENT|                 8|            837.33|             886.2|           9830.88|             87.25|             9.23|                0.21|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+--------------------+

# %%
holdings.show()
# Out:
# +----------+----+---------+-------+--------+--------+--------+--------+
# |Instrument|Qty.|Avg. cost|    LTP|Cur. val|     P&L|Net chg.|Day chg.|
# +----------+----+---------+-------+--------+--------+--------+--------+
# |ADANIPORTS|  15|   837.33|  886.2|   13293|  733.05|    5.84|   -0.24|
# |  ALLCARGO|  10|    377.6| 440.15|  4401.5|   625.5|   16.57|       0|
# | DEEPAKNTR|   2|  2073.75| 2211.5|    4423|   275.5|    6.64|       0|
# |  EXIDEIND|  40|   157.98|  190.6|    7624|  1304.7|   20.65|       0|
# |  HDFCLIFE|  16|   536.35|    590|    9440|   858.4|      10|       0|
# |HINDUNILVR|   8|  2557.43| 2615.3| 20922.4|     463|    2.26|       0|
# |    LANCER|   8|      364| 447.15|  3577.2|   665.2|   22.84|       0|
# | NIFTYBEES|  48|   190.57| 204.81| 9830.88|  683.46|    7.47|   -0.01|
# |  SAREGAMA|   5|   398.37|  381.9|  1909.5|  -82.35|   -4.13|       0|
# |SCHAEFFLER|  13|  2957.88| 2809.4| 36522.2|-1930.25|   -5.02|    0.21|
# |SHREDIGCEM|  20|    66.58|  70.25|    1405|    73.5|    5.52|       0|
# | TATASTEEL|  40|   101.55| 112.05|    4482|     420|   10.34|       0|
# |       TCS|  10|  3148.67|3439.25| 34392.5| 2905.85|    9.23|       0|
# |   TRIDENT| 125|    36.85|  37.55| 4693.75|   87.25|    1.89|       0|
# +----------+----+---------+-------+--------+--------+--------+--------+

# %%
holdings = holdings.withColumnRenamed('Qty.', 'Quantity').withColumnRenamed('Avg. cost', 'Average').withColumnRenamed('Cur. val','Current').withColumnRenamed('P&L','Profit_Loss').withColumnRenamed('Net chg.','Net_change').withColumnRenamed('Day chg.','Day_change')

# %%
holdings.filter(holdings['Profit_Loss']<0).show()
# Out:
# +----------+--------+-------+------+-------+-----------+----------+----------+
# |Instrument|Quantity|Average|   LTP|Current|Profit_Loss|Net_change|Day_change|
# +----------+--------+-------+------+-------+-----------+----------+----------+
# |  SAREGAMA|       5| 398.37| 381.9| 1909.5|     -82.35|     -4.13|         0|
# |SCHAEFFLER|      13|2957.88|2809.4|36522.2|   -1930.25|     -5.02|      0.21|
# +----------+--------+-------+------+-------+-----------+----------+----------+

# %%
holdings.sort(desc(holdings.LTP)).show()
# Out:
# +----------+--------+-------+-------+-------+-----------+----------+----------+
# |Instrument|Quantity|Average|    LTP|Current|Profit_Loss|Net_change|Day_change|
# +----------+--------+-------+-------+-------+-----------+----------+----------+
# |ADANIPORTS|      15| 837.33|  886.2|  13293|     733.05|      5.84|     -0.24|
# |SHREDIGCEM|      20|  66.58|  70.25|   1405|       73.5|      5.52|         0|
# |  HDFCLIFE|      16| 536.35|    590|   9440|      858.4|        10|         0|
# |    LANCER|       8|    364| 447.15| 3577.2|      665.2|     22.84|         0|
# |  ALLCARGO|      10|  377.6| 440.15| 4401.5|      625.5|     16.57|         0|
# |  SAREGAMA|       5| 398.37|  381.9| 1909.5|     -82.35|     -4.13|         0|
# |   TRIDENT|     125|  36.85|  37.55|4693.75|      87.25|      1.89|         0|
# |       TCS|      10|3148.67|3439.25|34392.5|    2905.85|      9.23|         0|
# |SCHAEFFLER|      13|2957.88| 2809.4|36522.2|   -1930.25|     -5.02|      0.21|
# |HINDUNILVR|       8|2557.43| 2615.3|20922.4|        463|      2.26|         0|
# | DEEPAKNTR|       2|2073.75| 2211.5|   4423|      275.5|      6.64|         0|
# | NIFTYBEES|      48| 190.57| 204.81|9830.88|     683.46|      7.47|     -0.01|
# |  EXIDEIND|      40| 157.98|  190.6|   7624|     1304.7|     20.65|         0|
# | TATASTEEL|      40| 101.55| 112.05|   4482|        420|     10.34|         0|
# +----------+--------+-------+-------+-------+-----------+----------+----------+
